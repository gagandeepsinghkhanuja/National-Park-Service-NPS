# %%
# Import all the libraries you need for the project
import requests
import pandas as pd
import os
import pprint 
import json

# %%
#API KEY is intentionally stored in a file to prevent misuse of it. 
with open('api_key_file.txt', 'r') as f:
    API_KEY = f.read().strip()
print("API Key: {}".format("API_KEY"))
# Out:
# API Key: API_KEY

# %%
# Pull URLs of all 50 states and append them to a file and store the metadata of all the 50 states in a list
url = 'https://developer.nps.gov/api/v1/parks?stateCode='
params = {
    'api_key': API_KEY,
    'fields': 'entranceFees',
    'limit': 100
    }
stateCode = [ 'AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA',
           'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME',
           'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM',
           'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
           'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY']
data = []
with open('NPS_urls.txt', 'a+') as f:
    for state in stateCode:
        r = requests.get(url+str(state), params)
        text = r.text
        data.append(json.loads(text))
        f.writelines(r.url+ '\n')
    f.close()

# %%
parks_data = pd.DataFrame(data)
print(parks_data)
# Out:
#    total limit start                                               data
# 0     19   100     0  [{'id': 'C4E1A9A4-D121-4734-94FA-7788A93C2AAA'...
# 1     11   100     0  [{'id': '99907F85-7E09-40FE-BF5E-A9AB7F09A7E2'...
# 2      8   100     0  [{'id': '6876F4F4-9B8F-4648-89EA-C1BBF770C494'...
# 3     24   100     0  [{'id': '869BAD2B-C46F-4FEB-891B-EBA119B64B48'...
# 4     33   100     0  [{'id': 'C08AD828-98FF-478E-A63C-614E7534274B'...
# 5     17   100     0  [{'id': 'D35004EF-5F5A-4DA4-8716-5141BE5C933C'...
# 6      5   100     0  [{'id': 'FAEF5684-83A4-4CF2-A701-60CF8D4014BD'...
# 7     36   100     0  [{'id': '1A47416F-DAA3-4137-9F30-14AF86B4E547'...
# 8      4   100     0  [{'id': '481CEBB8-1942-4FAE-8D89-9902E7B9EECA'...
# 9     10   100     0  [{'id': 'E0F4D5E3-3E4A-4345-B86A-1B0CAD7461F1'...
# 10    12   100     0  [{'id': '00E65872-53F7-4C9B-BD29-B9BC99930D0D'...
# 11     9   100     0  [{'id': '3B8307B3-54AB-4E5F-ACBC-8DECB98AD5F1'...
# 12     4   100     0  [{'id': '0265E5A4-576A-4626-882A-05971DEE9B76'...
# 13    10   100     0  [{'id': 'B39C368F-CB27-49EC-B2A9-E6C1552430FB'...
# 14     5   100     0  [{'id': '5D443C5F-19A0-4A06-9CE4-30534A3DD81A'...
# 15     4   100     0  [{'id': '48C4BDA1-98A3-441A-87FF-BAAB3AA043AE'...
# 16    10   100     0  [{'id': 'E2F59F29-1F3A-43B9-A361-7E74E5FDDEB1'...
# 17     9   100     0  [{'id': '77E0D7F0-1942-494A-ACE2-9004D2BDC59E'...
# 18     6   100     0  [{'id': '55ABA58B-B19E-4851-BDE1-1C0712B2BE2C'...
# 19    18   100     0  [{'id': 'E4C7784E-66A0-4D44-87D0-3E072F5FEF43'...
# 20    27   100     0  [{'id': '8415526C-C932-4236-A634-2D89DF718936'...
# 21     6   100     0  [{'id': '6DA17C86-088E-4B4D-B862-7C1BD5CF236B'...
# 22     6   100     0  [{'id': '0F6893CF-FC15-4AC5-8C95-E70FC9C21B1A'...
# 23     6   100     0  [{'id': 'E463E13F-FCD4-41B3-AEF3-BA3199E04399'...
# 24    13   100     0  [{'id': 'B39C368F-CB27-49EC-B2A9-E6C1552430FB'...
# 25     9   100     0  [{'id': 'F6555AB7-654F-4418-8827-F91F54536C04'...
# 26    10   100     0  [{'id': '3262234F-A56A-447D-AE6C-F5C734ABD3A4'...
# 27    12   100     0  [{'id': 'FAEF5684-83A4-4CF2-A701-60CF8D4014BD'...
# 28     5   100     0  [{'id': '60B1534B-5C3A-402A-ABC6-700B756F69A2'...
# 29    10   100     0  [{'id': '64B9F127-31ED-43C9-882D-D7CD471AF314'...
# 30     2   100     0  [{'id': 'FAEF5684-83A4-4CF2-A701-60CF8D4014BD'...
# 31    11   100     0  [{'id': 'FAEF5684-83A4-4CF2-A701-60CF8D4014BD'...
# 32    18   100     0  [{'id': 'CD54150B-24F6-4B96-8D6F-B23AF92A70F2'...
# 33     7   100     0  [{'id': 'B39C368F-CB27-49EC-B2A9-E6C1552430FB'...
# 34    32   100     0  [{'id': 'E6E1D22A-7A89-47F8-813C-B611059A8CF9'...
# 35    10   100     0  [{'id': '22177869-21C7-49A1-961C-3F2114F01007'...
# 36     6   100     0  [{'id': '16809469-7649-4DFA-9C76-57F2B9946DDC'...
# 37    10   100     0  [{'id': 'B39C368F-CB27-49EC-B2A9-E6C1552430FB'...
# 38    25   100     0  [{'id': '3350C18C-8E07-487B-930E-37AD873D31AD'...
# 39     4   100     0  [{'id': 'A36366E7-5663-4531-B0CE-D58928C6D01B'...
# 40     8   100     0  [{'id': '08EFF7E4-0FE4-4402-B23A-124EB8AAC249'...
# 41     7   100     0  [{'id': 'B170CCF7-7AB9-48FF-950E-31815FD4DBB2'...
# 42    15   100     0  [{'id': '2ED6E071-57AA-4B08-8DDA-5CB09FBB75C8'...
# 43    17   100     0  [{'id': '6D82D070-995A-4524-A56E-C1CE182E7D9B'...
# 44    17   100     0  [{'id': '36240051-018E-4915-B6EA-3F1A7F24FBE4'...
# 45    33   100     0  [{'id': 'FAEF5684-83A4-4CF2-A701-60CF8D4014BD'...
# 46     3   100     0  [{'id': 'FAEF5684-83A4-4CF2-A701-60CF8D4014BD'...
# 47    17   100     0  [{'id': '98C8117C-EDE9-4A7C-9354-5AD0DEFDB848'...
# 48     4   100     0  [{'id': 'D84122DD-1B0E-4D13-927C-5D6D2A0D200E'...
# 49     8   100     0  [{'id': 'FAEF5684-83A4-4CF2-A701-60CF8D4014BD'...
# 50    10   100     0  [{'id': '7568A0D8-73B1-44E6-82C7-E10BA1872209'...

# %%
pprint.pprint(parks_data['data'][0])
# Out:
# [{'activities': [{'id': '071BA73C-1D3C-46D4-A53C-00D5602F7F0E',
#                   'name': 'Boating'},
#                  {'id': 'A59947B7-3376-49B4-AD02-C0423E08C5F7',
#                   'name': 'Camping'},
#                  {'id': '4A58AF13-E8FB-4530-B41A-97DF0B0C77B7',
#                   'name': 'Backcountry Camping'},
#                  {'id': 'AE42B46C-E4B7-4889-A122-08FE180371AE',
#                   'name': 'Fishing'},
#                  {'id': '8386EEAF-985F-4DE8-9037-CCF91975AC94',
#                   'name': 'Hunting and Gathering'},
#                  {'id': '25559F45-F162-4B8B-BEC2-B341034A2AF4',
#                   'name': 'Hunting'},
#                  {'id': '4D224BCA-C127-408B-AC75-A51563C42411',
#                   'name': 'Paddling'},
#                  {'id': '256543C7-4322-48B3-8978-765E89AA9431',
#                   'name': 'Canoe or Kayak Camping'},
#                  {'id': 'F353A9ED-4A08-456E-8DEC-E61974D0FEB6',
#                   'name': 'Kayaking'},
#                  {'id': '75B92BEB-A36D-4064-88B7-92EEC6D17611',
#                   'name': 'Whitewater Rafting'},
#                  {'id': '0B685688-3405-4E2A-ABBA-E3069492EC50',
#                   'name': 'Wildlife Watching'},
#                  {'id': '5A2C91D1-50EC-4B24-8BED-A2E11A1892DF',
#                   'name': 'Birdwatching'}],
#   'addresses': [{'city': 'King Salmon',
#                  'line1': '1000 Silver St., Bldg. 603',
#                  'line2': 'PO Box 7',
#                  'line3': '',
#                  'postalCode': '99613',
#                  'stateCode': 'AK',
#                  'type': 'Physical'},
#                 {'city': 'King Salmon',
#                  'line1': 'PO Box 245',
#                  'line2': '',
#                  'line3': '',
#                  'postalCode': '99613',
#                  'stateCode': 'AK',
#                  'type': 'Mailing'}],
#   'contacts': {'emailAddresses': [{'description': '',
#                                    'emailAddress': 'KATM_Visitor_Information@nps.gov'}],
#                'phoneNumbers': [{'description': '',
#                                  'extension': '',
#                                  'phoneNumber': '9072463305',
#                                  'type': 'Voice'}]},
#   'description': 'The headwaters of Alagnak Wild River lie within the rugged '
#                  'Aleutian Range of neighboring Katmai National Park and '
#                  'Preserve. Meandering west towards Bristol Bay and the Bering '
#                  'Sea, the Alagnak traverses the beautiful Alaska Peninsula, '
#                  'providing an unparalleled opportunity to experience the '
#                  'unique wilderness, wildlife, and cultural heritage of '
#                  'southwest Alaska.',
#   'designation': 'Wild River',
#   'directionsInfo': 'Alagnak Wild River is located in a remote part of the '
#                     'Alaska Peninsula, about 290 miles southwest of Anchorage. '
#                     'Access is by boat or small floatplane.',
#   'directionsUrl': 'http://www.nps.gov/alag/planyourvisit/directions.htm',
#   'entranceFees': [{'cost': '0.00',
#                     'description': 'None. There is no fee',
#                     'title': 'No Entrance Free'}],
#   'entrancePasses': [],
#   'fees': [],
#   'fullName': 'Alagnak Wild River',
#   'id': 'C4E1A9A4-D121-4734-94FA-7788A93C2AAA',
#   'images': [{'altText': 'underwater photo of salmon swimming in river',
#               'caption': 'Each summer, hundreds of thousands of salmon return '
#                          'to the Alagnak watershed to spawn.',
#               'credit': 'NPS/R. Wood',
#               'title': 'salmon in Alagnak River',
#               'url': 'https://www.nps.gov/common/uploads/structured_data/3C7E810E-1DD8-B71B-0B92FDF31F5C0CA6.jpg'},
#              {'altText': 'inflatable rafts on the edge of a river',
#               'caption': 'Rafting is a popular way to experience the river.',
#               'credit': 'NPS/R. Wood',
#               'title': 'Rafts along the river',
#               'url': 'https://www.nps.gov/common/uploads/structured_data/3C7E8259-1DD8-B71B-0B45810F0CB6E02C.jpg'},
#              {'altText': 'aerial view of braided Alagnak River',
#               'caption': "Alagnak River's lower reaches are extremely braided.",
#               'credit': 'NPS',
#               'title': 'Alagnak Wild River',
#               'url': 'https://www.nps.gov/common/uploads/structured_data/3C7E8391-1DD8-B71B-0BB3E18B7F96110A.jpg'}],
#   'latLong': 'lat:59.05180188, long:-156.112002',
#   'latitude': '59.05180188',
#   'longitude': '-156.112002',
#   'name': 'Alagnak',
#   'operatingHours': [{'description': 'Alagnak Wild River is never closed, but '
#                                      'access can be difficult during the '
#                                      'winter.',
#                       'exceptions': [],
#                       'name': 'Alagnak Wild River',
#                       'standardHours': {'friday': 'All Day',
#                                         'monday': 'All Day',
#                                         'saturday': 'All Day',
#                                         'sunday': 'All Day',
#                                         'thursday': 'All Day',
#                                         'tuesday': 'All Day',
#                                         'wednesday': 'All Day'}}],
#   'parkCode': 'alag',
#   'states': 'AK',
#   'topics': [{'id': '7F81A0CB-B91F-4896-B9A5-41BE9A54A27B',
#               'name': 'Archeology'},
#              {'id': '0D00073E-18C3-46E5-8727-2F87B112DDC6', 'name': 'Animals'},
#              {'id': '957EF2BD-AC6C-4B7B-BD9A-87593ADC6691', 'name': 'Birds'},
#              {'id': '1608649A-E7D7-4529-BD83-074C90F9FB68', 'name': 'Fish'},
#              {'id': '77B7EFDF-1A74-409C-8BA2-324EC919DB0E', 'name': 'Arctic'},
#              {'id': 'C8F16A24-90B7-47D9-B2E0-5F2A9237D0F4', 'name': 'Tundra'},
#              {'id': '4BE01DC5-52E6-4F18-8C9A-B22D65965F6D',
#               'name': 'Groundwater'},
#              {'id': 'A155238F-0DD2-4610-9B87-05FCE1C59283',
#               'name': 'River and Riparian'},
#              {'id': '1365C347-952C-475A-B755-731DD523C195', 'name': 'Wetlands'},
#              {'id': 'B85866E2-0897-4000-9040-605CA335804F',
#               'name': 'Wilderness'}],
#   'url': 'https://www.nps.gov/alag/index.htm',
#   'weatherInfo': 'Located between the stormy north Pacific Ocean and the even '
#                  'stormier Bering Sea, the Alagnak Wild River is often a '
#                  'battleground between weather systems. When you visit, be '
#                  'prepared to encounter all types of weather.\xa0\xa0On '
#                  'average, wet and cool conditions predominate in spring, '
#                  'summer, and fall. Winters are drier and colder.'},
#  {'activities': [],
#   'addresses': [{'city': 'Anchorage',
#                  'line1': '605 West 4th Avenue',
#                  'line2': 'Suite 105',
#                  'line3': '',
#                  'postalCode': '99501',
#                  'stateCode': 'AK',
#                  'type': 'Physical'},
#                 {'city': 'Anchorage',
#                  'line1': '605 West 4th Avenue',
#                  'line2': 'Suite 105',
#                  'line3': '',
#                  'postalCode': '99501',
#                  'stateCode': 'AK',
#                  'type': 'Mailing'}],
#   'contacts': {'emailAddresses': [{'description': '',
#                                    'emailAddress': 'anch_web_mail@nps.gov'}],
#                'phoneNumbers': [{'description': '',
#                                  'extension': '',
#                                  'phoneNumber': '9076443661',
#                                  'type': 'Voice'},
#                                 {'description': '',
#                                  'extension': '',
#                                  'phoneNumber': '9072712744',
#                                  'type': 'Fax'},
#                                 {'description': '',
#                                  'extension': '',
#                                  'phoneNumber': '8668696887',
#                                  'type': 'TTY'}]},
#   'description': 'Alaska’s parks, forests, and refuges are rich and varied. '
#                  'The Alaska Public Lands Information Centers help visitors '
#                  'and residents to have meaningful, safe, enjoyable '
#                  'experiences on public lands, and encourages them to sustain '
#                  'the natural and cultural resources of Alaska. These centers '
#                  'provide trip-planning, interpretation, and education for all '
#                  'ages.',
#   'designation': '',
#   'directionsInfo': 'Anchorage APLIC is located in downtown Anchorage on 4th '
#                     'Avenue, in the Federal Building. Fairbanks APLIC is '
#                     'located in downtown Fairbanks on the corner of Dunkel '
#                     'Street and Wendell Avenue, near the Chena River.',
#   'directionsUrl': 'http://alaskacenters.gov/anchorage-directions.cfm',
#   'entranceFees': [{'cost': '0.00',
#                     'description': 'No entry fee to visit the visitors center',
#                     'title': 'Free Admittance'}],
#   'entrancePasses': [],
#   'fees': [],
#   'fullName': 'Alaska Public Lands',
#   'id': '7D6098F9-3F75-4775-A56D-CD9C7F9A9488',
#   'images': [{'altText': 'Two Hikers stand on top of a very large granite '
#                          'boulder, looking out across the landscape',
#               'caption': 'Hikers on top of Angel Rocks near Fairbanks look out '
#                          'across the landscape of Chena River State Recreation '
#                          'Area',
#               'credit': 'NPS/Josh Spice',
#               'title': 'Hikers on Angel Rocks',
#               'url': 'https://www.nps.gov/common/uploads/structured_data/2595FA12-DF7A-1B6C-55D8F41ABCA2E011.jpg'},
#              {'altText': 'Front of the Anchorage Federal Building, housing the '
#                          'Anchorage APLIC',
#               'caption': 'The Anchorage APLIC is located inside the Federal '
#                          'Building',
#               'credit': 'NPS',
#               'title': 'Anchorage APLIC',
#               'url': 'https://www.nps.gov/common/uploads/structured_data/3C86397B-1DD8-B71B-0B8F02FE5D76B46D.jpg'},
#              {'altText': 'Fairbanks Alaska Public Lands Information Center, '
#                          'located inside the Morris Thompson Cultural & Visi',
#               'caption': 'Fairbanks Alaska Public Lands Information Center, '
#                          'located inside the Morris Thompson Cultural & '
#                          'Visitors Center, in summer',
#               'credit': 'NPS/Josh Spice',
#               'title': 'Fairbanks APLIC',
#               'url': 'https://www.nps.gov/common/uploads/structured_data/3C860F61-1DD8-B71B-0B4E7399BE80347C.jpg'}],
#   'latLong': 'lat:61.2188, long:-149.894536',
#   'latitude': '61.2188',
#   'longitude': '-149.894536',
#   'name': 'Alaska Public Lands',
#   'operatingHours': [{'description': 'Summer Hours: 9-5, Every Day, Late May '
#                                      'to Mid September, Open Federal Holidays\n'
#                                      'Winter Hours: 10-5, Mon-Thur, closed for '
#                                      'lunch 12-1, September to Early May, '
#                                      'Closed Federal Holidays',
#                       'exceptions': [{'endDate': '2023-05-01',
#                                       'exceptionHours': {'friday': 'Closed',
#                                                          'monday': 'Closed',
#                                                          'saturday': 'Closed',
#                                                          'sunday': 'Closed',
#                                                          'thursday': 'Closed',
#                                                          'tuesday': 'Closed',
#                                                          'wednesday': 'Closed'},
#                                       'name': 'COVID-19 Closure',
#                                       'startDate': '2022-12-15'}],
#                       'name': 'Anchorage Hours',
#                       'standardHours': {'friday': 'Closed',
#                                         'monday': 'Closed',
#                                         'saturday': 'Closed',
#                                         'sunday': 'Closed',
#                                         'thursday': 'Closed',
#                                         'tuesday': 'Closed',
#                                         'wednesday': 'Closed'}},
#                      {'description': 'Summer Hours: 8-6, Every Day, Memorial '
#                                      'Day through Labor Day, Open Federal '
#                                      'Holidays\n'
#                                      'Winter Hours: 8-5, Mon-Sat, Labor Day '
#                                      'through Memorial Day, Closed Federal '
#                                      'Holidays\n'
#                                      '\n'
#                                      '101 Dunkel Street Suite 110\n'
#                                      'Fairbanks, AK 99701\n'
#                                      '\n'
#                                      'Telephone: 907.459.3730\n'
#                                      'Fax: 907.459.3729\n'
#                                      'Email: fair_interpretation@nps.gov',
#                       'exceptions': [{'endDate': '2023-05-30',
#                                       'exceptionHours': {'friday': '8:00AM - '
#                                                                    '5:00PM',
#                                                          'monday': '8:00AM - '
#                                                                    '5:00PM',
#                                                          'saturday': '8:00AM - '
#                                                                      '5:00PM',
#                                                          'sunday': 'Closed',
#                                                          'thursday': '8:00AM - '
#                                                                      '5:00PM',
#                                                          'tuesday': '8:00AM - '
#                                                                     '5:00PM',
#                                                          'wednesday': '8:00AM '
#                                                                       '- '
#                                                                       '5:00PM'},
#                                       'name': 'Winter Hours',
#                                       'startDate': '2022-09-04'}],
#                       'name': 'Fairbanks Hours',
#                       'standardHours': {'friday': '8:00AM - 6:00PM',
#                                         'monday': '8:00AM - 6:00PM',
#                                         'saturday': '8:00AM - 6:00PM',
#                                         'sunday': '8:00AM - 6:00PM',
#                                         'thursday': '8:00AM - 6:00PM',
#                                         'tuesday': '8:00AM - 6:00PM',
#                                         'wednesday': '8:00AM - 6:00PM'}}],
#   'parkCode': 'anch',
#   'states': 'AK',
#   'topics': [],
#   'url': 'https://www.nps.gov/anch/index.htm',
#   'weatherInfo': 'Visitors center is located inside the Federal Building and '
#                  'weather conditions are seasonal conditions of the Anchorage '
#                  'area, outside the facility.'},
#  {'activities': [{'id': 'B33DC9B6-0B7D-4322-BAD7-A13A34C584A3',
#                   'name': 'Guided Tours'},
#                  {'id': 'A0631906-9672-4583-91DE-113B93DB6B6E',
#                   'name': 'Self-Guided Tours - Walking'},
#                  {'id': 'C7D5A145-F8EB-4C37-9E92-2F6C6206B196',
#                   'name': 'Self-Guided Tours - Auto'},
#                  {'id': 'DF4A35E0-7983-4A3E-BC47-F37B872B0F25',
#                   'name': 'Junior Ranger Program'},
#                  {'id': '0B685688-3405-4E2A-ABBA-E3069492EC50',
#                   'name': 'Wildlife Watching'},
#                  {'id': '5A2C91D1-50EC-4B24-8BED-A2E11A1892DF',
#                   'name': 'Birdwatching'},
#                  {'id': 'C8F98B28-3C10-41AE-AA99-092B3B398C43',
#                   'name': 'Museum Exhibits'}],
#   'addresses': [{'city': 'Anchorage',
#                  'line1': 'Affiliated Areas, Alaska Regional Office',
#                  'line2': 'National Park Service',
#                  'line3': '240 W 5th Avenue',
#                  'postalCode': '99501',
#                  'stateCode': 'AK',
#                  'type': 'Physical'},
#                 {'city': 'Anchorage',
#                  'line1': 'Affiliated Areas, Alaska Regional Office',
#                  'line2': 'National Park Service',
#                  'line3': '240 W 5th Avenue',
#                  'postalCode': '99501',
#                  'stateCode': 'AK',
#                  'type': 'Mailing'}],
#   'contacts': {'emailAddresses': [{'description': '',
#                                    'emailAddress': 'rachel_mason@nps.gov'}],
#                'phoneNumbers': [{'description': '',
#                                  'extension': '',
#                                  'phoneNumber': '9076443472',
#                                  'type': 'Voice'}]},
#   'description': 'During World War II the remote Aleutian Islands, home to the '
#                  'Unangax̂ (Aleut) people for over 8,000 years, became a '
#                  'fiercely contested battleground in the Pacific. This '
#                  'thousand-mile-long archipelago saw invasion by Japanese '
#                  'forces, the occupation of two islands; a mass relocation of '
#                  'Unangax̂ civilians; a 15-month air war; and one of the '
#                  'deadliest battles in the Pacific Theater.',
#   'designation': 'National Historic Area',
#   'directionsInfo': 'The park is located on Amaknak Island in the Aleutian '
#                     'Island chain. The island is located 800 miles west of '
#                     'Anchorage. The island can be reached by commercial or '
#                     'charter air flights from Anchorage. Commercial flights to '
#                     'Unalaska include Pen Air and Alaska Airlines. The Alaska '
#                     'Marine Highway is a ferry service that is operated by the '
#                     'state that can be used to reach the island. The Aleutian '
#                     'World War II Visitor Center is located at the Unalaska '
#                     'airport.',
#   'directionsUrl': 'http://www.nps.gov/aleu/planyourvisit/directions.htm',
#   'entranceFees': [{'cost': '6.00',
#                     'description': 'The park is on private land owned by the '
#                                    'Ounalashka Corporation.  To visit the '
#                                    'historic area you need to purchase a '
#                                    'permit.',
#                     'title': 'Land Use Permit - one person'},
#                    {'cost': '10.00',
#                     'description': 'The park is on private land owned by the '
#                                    'Ounalashka Corporation.  To visit the '
#                                    'historic area you need to purchase a '
#                                    'permit.',
#                     'title': 'Land Use Permit - family'}],
#   'entrancePasses': [],
#   'fees': [],
#   'fullName': 'Aleutian Islands World War II National Historic Area',
#   'id': '94B046DC-2AFD-4ECB-A60D-CE210A8550B1',
#   'images': [{'altText': 'Group of people around a Russian cross in tall grass',
#               'caption': 'In September 2009, Nick Lekanoff, Sr., former '
#                          'Makushin resident, traveled with his daughter and '
#                          'other descendants of Makushin on the Tiglax to visit '
#                          'the village site, which had been left behind in the '
#                          'evacuation of 1942 and never permanently resettled.',
#               'credit': 'NPS Photo',
#               'title': 'A homeland changed',
#               'url': 'https://www.nps.gov/common/uploads/structured_data/3C7BC1AE-1DD8-B71B-0BF60FDE7A21822B.jpg'},
#              {'altText': 'Twelve men and a dog pose for a photo',
#               'caption': 'After his aerological crew was captured by the '
#                          'Japanese in June, 1942, Senior Petty Officer William '
#                          'House survived 50 days in the hills of Kiska.  He '
#                          'ate grass, shellfish, and worms. Weighing 80lbs he '
#                          'surrendered and was respected for his perseverance.',
#               'credit': 'Photograph courtesy National Archives',
#               'title': 'William C. House and the Aerological Detail on Kiska',
#               'url': 'https://www.nps.gov/common/uploads/structured_data/3C7BC37B-1DD8-B71B-0BA4AF7F3700FE86.jpg'},
#              {'altText': 'People crowd at the railing of a ship',
#               'caption': 'Pribilof villagers, here lining the railing of the '
#                          'USAT Delarof on the day of their departure (June 15, '
#                          '1942), were evacuated with only a few hours notice '
#                          'and no idea of their ultimate destination.',
#               'credit': 'Photograph courtesy National Archives',
#               'title': 'Evacuation and internment',
#               'url': 'https://www.nps.gov/common/uploads/structured_data/3C7BC517-1DD8-B71B-0BD7C869F63B3276.jpg'},
#              {'altText': 'Four men gather around a invalid man',
#               'caption': 'Soldiers rub the frostbitten feet of a disabled '
#                          'soldier. Over 2000 weather-related casualties—the '
#                          'majority Attu feet—were recorded for U.S. troops. '
#                          'This number represents the largest classification of '
#                          'casualties suffered by American forces on the '
#                          'island.',
#               'credit': 'Photo courtesy of National Archives',
#               'title': 'Challenging weather conditions',
#               'url': 'https://www.nps.gov/common/uploads/structured_data/3C7BC68B-1DD8-B71B-0BED69DAACF6A5AC.jpg'},
#              {'altText': 'Six men with guns carry a person on a stretcher in a '
#                          'valley.',
#               'caption': 'U.S. wounded are gathered from the battlefield on '
#                          'Attu Island.  The battle on Attu, lasting nearly 20 '
#                          'days, was the second most deadly in the Pacific '
#                          'Theater.',
#               'credit': 'Photo courtesy National Archives',
#               'title': 'The battle for Attu Island',
#               'url': 'https://www.nps.gov/common/uploads/structured_data/3C7BC7CF-1DD8-B71B-0B73637962E06C74.jpg'},
#              {'altText': 'A uniformed man holds up a broken Russian cross',
#               'caption': 'The Aleutian campaign brought together Russian, '
#                          'Native Alaskan, Japanese, and Euroamerican cultures. '
#                          'During the war 7 historic churches were damaged or '
#                          'destroyed. Villages were unrecognizable or burned to '
#                          'the ground and personal belonging lost or stolen.',
#               'credit': 'Photo courtesy National Archives',
#               'title': 'Cultural collision',
#               'url': 'https://www.nps.gov/common/uploads/structured_data/3C7BC97B-1DD8-B71B-0B9A70C0C0988F0E.jpg'}],
#   'latLong': 'lat:53.9143, long:-166.5197',
#   'latitude': '53.9143',
#   'longitude': '-166.5197',
#   'name': 'Aleutian Islands World War II',
#   'operatingHours': [{'description': '',
#                       'exceptions': [{'endDate': '2023-07-04',
#                                       'exceptionHours': {'friday': 'Closed',
#                                                          'monday': 'Closed',
#                                                          'saturday': 'Closed',
#                                                          'thursday': 'Closed',
#                                                          'tuesday': 'Closed',
#                                                          'wednesday': 'Closed'},
#                                       'name': 'Fourth of July',
#                                       'startDate': '2023-07-04'},
#                                      {'endDate': '2023-05-30',
#                                       'exceptionHours': {'friday': 'Closed',
#                                                          'monday': 'Closed',
#                                                          'saturday': 'Closed',
#                                                          'thursday': 'Closed',
#                                                          'tuesday': 'Closed',
#                                                          'wednesday': 'Closed'},
#                                       'name': 'Winter',
#                                       'startDate': '2022-09-04'}],
#                       'name': 'Summer Hours',
#                       'standardHours': {'friday': '9:00AM - 10:00AM',
#                                         'monday': '9:00AM - 10:00AM',
#                                         'saturday': '9:00AM - 10:00AM',
#                                         'sunday': '9:00AM - 10:00AM',
#                                         'thursday': '9:00AM - 10:00AM',
#                                         'tuesday': '9:00AM - 10:00AM',
#                                         'wednesday': '9:00AM - 10:00AM'}}],
#   'parkCode': 'aleu',
#   'states': 'AK',
#   'topics': [{'id': '7F81A0CB-B91F-4896-B9A5-41BE9A54A27B',
#               'name': 'Archeology'},
#              {'id': 'B912363F-771C-4098-BA3A-938DF38A9D7E', 'name': 'Aviation'},
#              {'id': '7F12224B-217A-4B07-A4A2-636B1CE7F221',
#               'name': 'Colonization and Settlement'},
#              {'id': '988B4AFC-F478-4673-B66D-E6BDB0CCFF35', 'name': 'Forts'},
#              {'id': '351EE154-87AA-46B0-BBA1-ED604368ACE9',
#               'name': 'Incarceration'},
#              {'id': '4C9D4777-A9DA-47D1-A0B9-F4A3C98BC1B3', 'name': 'Maritime'},
#              {'id': '123CE28E-0EFA-4330-8E6E-EEFF3D7BF772',
#               'name': 'Coastal Defenses'},
#              {'id': '7424754D-EB8B-4608-A69A-50D44992931B',
#               'name': 'Maritime - Military'},
#              {'id': 'A079385C-3E71-4E18-9E42-B046BC22EA95',
#               'name': 'Ships and Shipwrecks'},
#              {'id': '3B0D607D-9933-425A-BFA0-21529AC4734C', 'name': 'Military'},
#              {'id': '97CCB419-196C-4B95-BB3A-621458F78415', 'name': 'US Army'},
#              {'id': '7A9F5EB5-4AE3-4A16-AFF0-E1F9FF2F8B32', 'name': 'US Navy'},
#              {'id': '64808223-DD03-40ED-99A1-76183E7AB1F5',
#               'name': 'US Marines'},
#              {'id': 'D164D82F-4031-4BCB-90A8-B388502CA308',
#               'name': 'US Coast Guard'},
#              {'id': '83CEA23E-9FF6-4C6B-B48E-A725087D5CC5',
#               'name': 'US Air Force (Army Air Corps)'},
#              {'id': '6766B838-9493-4EF8-830E-2D1EFB917461',
#               'name': 'Indigenous and Native Warrior'},
#              {'id': '6A3658B4-FB6E-4E23-A63A-9AEF11988831',
#               'name': 'Battlefields'},
#              {'id': 'BEB7E470-13B2-4E00-84B2-0402D98DAF69',
#               'name': 'Monuments and Memorials'},
#              {'id': 'A1BAF33E-EA84-4608-A888-4CEE9541F027',
#               'name': 'Native American Heritage'},
#              {'id': '518B32FB-339D-4C52-B2C2-04BF406AA4B0',
#               'name': 'Religion and Spirituality'},
#              {'id': 'A160B3D9-1603-4D89-B82F-21FCAF9EEE3B',
#               'name': 'Tragic Events'},
#              {'id': '8CDF78C9-F91A-4ACD-AE70-4FF186F616CE',
#               'name': 'Forced Marches'},
#              {'id': 'CB405E14-E2A3-4C2E-A91C-AFF8AEB3DEA0',
#               'name': 'Massacres'},
#              {'id': '27BF8807-54EA-4A3D-B073-AA7AA361CD7E',
#               'name': 'Wars and Conflicts'},
#              {'id': '74869FAE-8DFD-4454-847F-11FDDB679F94',
#               'name': 'World War II'},
#              {'id': '77B7EFDF-1A74-409C-8BA2-324EC919DB0E', 'name': 'Arctic'},
#              {'id': 'C8F16A24-90B7-47D9-B2E0-5F2A9237D0F4', 'name': 'Tundra'},
#              {'id': '46FC5CBD-9AD5-48F1-B4DA-1357031B1D2E',
#               'name': 'Coasts, Islands and Atolls'},
#              {'id': '101F4D51-F99D-45A6-BBB6-CD481E5FACED',
#               'name': 'Mountains'},
#              {'id': '9C9FCBB6-360B-4743-8155-6F9341CBE01B',
#               'name': 'Scenic Views'}],
#   'url': 'https://www.nps.gov/aleu/index.htm',
#   'weatherInfo': 'The Aleutian Islands are known for unpredictable and stormy '
#                  'weather. Rain, fog, and wind are common. Dress warmly and '
#                  'carry rain gear even in summer. Summer temperatures range '
#                  'from 45 to 65 degrees F. Early summer and fall often have '
#                  'clear sunny days with spectacular views of the surrounding '
#                  'volcanoes. See forecast: '
#                  'https://forecast.weather.gov/MapClick.php?lon=-166.52406692504883&lat=53.91748321582622#.X0aTYsi6OUk'},
#  {'activities': [{'id': 'A59947B7-3376-49B4-AD02-C0423E08C5F7',
#                   'name': 'Camping'},
#                  {'id': '4A58AF13-E8FB-4530-B41A-97DF0B0C77B7',
#                   'name': 'Backcountry Camping'},
#                  {'id': 'B12FAAB9-713F-4B38-83E4-A273F5A43C77',
#                   'name': 'Climbing'},
#                  {'id': '977B3209-68A2-4BCE-97A9-EA0CAC320664',
#                   'name': 'Mountain Climbing'},
#                  {'id': 'D72206E4-6CD1-4441-A355-F8F1827466B1',
#                   'name': 'Flying'},
#                  {'id': 'BFF8C027-7C8F-480B-A5F8-CD8CE490BFBA',
#                   'name': 'Hiking'},
#                  {'id': '7C37B79B-D02D-49EB-9020-3DB8299B748A',
#                   'name': 'Backcountry Hiking'},
#                  {'id': '4D224BCA-C127-408B-AC75-A51563C42411',
#                   'name': 'Paddling'},
#                  {'id': '75B92BEB-A36D-4064-88B7-92EEC6D17611',
#                   'name': 'Whitewater Rafting'},
#                  {'id': '0B685688-3405-4E2A-ABBA-E3069492EC50',
#                   'name': 'Wildlife Watching'},
#                  {'id': '5A2C91D1-50EC-4B24-8BED-A2E11A1892DF',
#                   'name': 'Birdwatching'}],
#   'addresses': [{'city': 'KIng Salmon',
#                  'line1': '1000 Silver St., Bldg. 603',
#                  'line2': 'PO Box 7',
#                  'line3': '',
#                  'postalCode': '99613',
#                  'stateCode': 'AK',
#                  'type': 'Physical'},
#                 {'city': 'KIng Salmon',
#                  'line1': 'PO Box 245',
#                  'line2': '',
#                  'line3': '',
#                  'postalCode': '99613',
#                  'stateCode': 'AK',
#                  'type': 'Mailing'}],
#   'contacts': {'emailAddresses': [{'description': '',
#                                    'emailAddress': 'KATM_Visitor_Information@nps.gov'}],
#                'phoneNumbers': [{'description': '',
#                                  'extension': '',
#                                  'phoneNumber': '9072463305',
#                                  'type': 'Voice'}]},
#   'description': 'Given its remote location and challenging weather '
#                  'conditions, Aniakchak is one of the most wild and least '
#                  'visited places in the National Park System. This landscape '
#                  "is a vibrant reminder of Alaska's location in the "
#                  'volcanically active "Ring of Fire," as it is home to an '
#                  'impressive six mile (10 km) wide, 2,500 ft (762 m) deep '
#                  'caldera formed during a massive volcanic eruption 3,500 '
#                  'years ago.',
#   'designation': 'National Monument & Preserve',
#   'directionsInfo': 'Located on the Alaska Peninsula, 450 miles southwest of '
#                     'Anchorage, Aniakchak National Monument and Preserve is '
#                     'inaccessible by road. Notoriously bad weather makes '
#                     'access to Aniakchak unpredictable. Drop-offs and/or '
#                     'pick-ups may be significantly delayed.',
#   'directionsUrl': 'http://www.nps.gov/ania/planyourvisit/directions.htm',
#   'entranceFees': [{'cost': '0.00',
#                     'description': 'There is no fee to enter Aniakchak '
#                                    'National Monument and Preserve',
#                     'title': 'No Entrance Fee'}],
#   'entrancePasses': [],
#   'fees': [],
#   'fullName': 'Aniakchak National Monument & Preserve',
#   'id': '7FF37F14-88C8-469E-A447-ACE6D9AF44D2',
#   'images': [{'altText': 'A lone raft floats the Aniakchak Wild River as it '
#                          'flows through the "Gates"',
#               'caption': 'A lone raft floats the Aniakchak Wild River as it '
#                          'flows through the "Gates"',
#               'credit': 'NPS Photo/Troy Hamon',
#               'title': 'Floating the Gates of Aniakchak',
#               'url': 'https://www.nps.gov/common/uploads/structured_data/3C7A78AD-1DD8-B71B-0BF20886BAA0C0DA.jpg'},
#              {'altText': 'Aerial shot of Aniakchak Caldera',
#               'caption': 'Aerial shot of Aniakchak Caldera',
#               'credit': 'NPS Photo/Roy Wood',
#               'title': 'Aniakchak Caldera',
#               'url': 'https://www.nps.gov/common/uploads/structured_data/3C7A7A2E-1DD8-B71B-0BF4777A154558A4.jpg'},
#              {'altText': 'Black Nose, Aniakchak Caldera',
#               'caption': 'Black Nose, Aniakchak Caldera',
#               'credit': 'NPS Photo/Roy Wood',
#               'title': 'Black Nose, Aniakchak Caldera',
#               'url': 'https://www.nps.gov/common/uploads/structured_data/3C7A7D1E-1DD8-B71B-0B03A4FBF4D86D31.jpg'},
#              {'altText': 'Maar Lake, Aniakchak Caldera',
#               'caption': 'Maar Lake, Aniakchak Caldera',
#               'credit': 'NPS Photo/Roy Wood',
#               'title': 'Maar Lake, Aniakchak Caldera',
#               'url': 'https://www.nps.gov/common/uploads/structured_data/3C7A7E85-1DD8-B71B-0BEDEFFC89815B42.jpg'},
#              {'altText': 'The Gates of Aniakchak',
#               'caption': 'The Gates of Aniakchak',
#               'credit': 'NPS Photo/Roy Wood',
#               'title': 'The Gates of Aniakchak',
#               'url': 'https://www.nps.gov/common/uploads/structured_data/3C7A7FDE-1DD8-B71B-0B357DE404A64A20.jpg'}],
#   'latLong': 'lat:56.85317675, long:-157.5544362',
#   'latitude': '56.85317675',
#   'longitude': '-157.5544362',
#   'name': 'Aniakchak',
#   'operatingHours': [{'description': 'Aniakchak National Monument is a truly '
#                                      'primitive environment with no '
#                                      'federally-maintained public facilities. '
#                                      'The NPS imposes no operating hours or '
#                                      'seasonal restrictions. Access to and '
#                                      'movement within Aniachak, however, may '
#                                      'be limited or restricted at any time '
#                                      'depending upon prevailing weather '
#                                      'conditions.',
#                       'exceptions': [],
#                       'name': 'Aniakchak National Monument and Preserve',
#                       'standardHours': {'friday': 'All Day',
#                                         'monday': 'All Day',
#                                         'saturday': 'All Day',
#                                         'sunday': 'All Day',
#                                         'thursday': 'All Day',
#                                         'tuesday': 'All Day',
#                                         'wednesday': 'All Day'}}],
#   'parkCode': 'ania',
#   'states': 'AK',
#   'topics': [{'id': '7F81A0CB-B91F-4896-B9A5-41BE9A54A27B',
#               'name': 'Archeology'},
#              {'id': '0D00073E-18C3-46E5-8727-2F87B112DDC6', 'name': 'Animals'},
#              {'id': '77B7EFDF-1A74-409C-8BA2-324EC919DB0E', 'name': 'Arctic'},
#              {'id': 'C8F16A24-90B7-47D9-B2E0-5F2A9237D0F4', 'name': 'Tundra'},
#              {'id': 'F16A7A2C-174D-4FD8-9203-8D8D8EAD644B',
#               'name': 'Geothermal'},
#              {'id': '101F4D51-F99D-45A6-BBB6-CD481E5FACED',
#               'name': 'Mountains'},
#              {'id': '90F8744F-CD10-4925-955C-064CB1A17EB0',
#               'name': 'Volcanoes'},
#              {'id': 'B85866E2-0897-4000-9040-605CA335804F',
#               'name': 'Wilderness'}],
#   'url': 'https://www.nps.gov/ania/index.htm',
#   'weatherInfo': 'When you visit, be prepared to encounter all types of '
#                  'weather. On average, wet and cool conditions predominate in '
#                  'spring, summer, and fall. Strong winds can delay the '
#                  'departure and arrival of boats and floatplanes.'},
#  {'activities': [{'id': 'A59947B7-3376-49B4-AD02-C0423E08C5F7',
#                   'name': 'Camping'},
#                  {'id': '4A58AF13-E8FB-4530-B41A-97DF0B0C77B7',
#                   'name': 'Backcountry Camping'},
#                  {'id': '8C495067-8E94-4D78-BBD4-3379DACF6550',
#                   'name': 'Dog Sledding'},
#                  {'id': 'D72206E4-6CD1-4441-A355-F8F1827466B1',
#                   'name': 'Flying'},
#                  {'id': 'C06FE528-9671-4EC1-909F-B7D3720A1D89',
#                   'name': 'Fixed Wing Flying'},
#                  {'id': 'BFF8C027-7C8F-480B-A5F8-CD8CE490BFBA',
#                   'name': 'Hiking'},
#                  {'id': '7C37B79B-D02D-49EB-9020-3DB8299B748A',
#                   'name': 'Backcountry Hiking'},
#                  {'id': '8386EEAF-985F-4DE8-9037-CCF91975AC94',
#                   'name': 'Hunting and Gathering'},
#                  {'id': '8286295F-0932-4491-9350-280C9848E6AB',
#                   'name': 'Gathering and Foraging'},
#                  {'id': 'DF4A35E0-7983-4A3E-BC47-F37B872B0F25',
#                   'name': 'Junior Ranger Program'},
#                  {'id': '7C912B83-1B1B-4807-9B66-97C12211E48E',
#                   'name': 'Snowmobiling'},
#                  {'id': '0B685688-3405-4E2A-ABBA-E3069492EC50',
#                   'name': 'Wildlife Watching'},
#                  {'id': '5A2C91D1-50EC-4B24-8BED-A2E11A1892DF',
#                   'name': 'Birdwatching'}],
#   'addresses': [{'city': 'Nome',
#                  'line1': '214 Front St.',
#                  'line2': 'Sitnasuak Building',
#                  'line3': '',
#                  'postalCode': '99762',
#                  'stateCode': 'AK',
#                  'type': 'Physical'},
#                 {'city': 'Nome',
#                  'line1': 'P.O. Box 220',
#                  'line2': '',
#                  'line3': '',
#                  'postalCode': '99762',
#                  'stateCode': 'AK',
#                  'type': 'Mailing'}],
#   'contacts': {'emailAddresses': [{'description': '',
#                                    'emailAddress': 'bela_interpretation@nps.gov'}],
#                'phoneNumbers': [{'description': '',
#                                  'extension': '',
#                                  'phoneNumber': '8004712352',
#                                  'type': 'Voice'},
#                                 {'description': '',
#                                  'extension': '',
#                                  'phoneNumber': '9074436139',
#                                  'type': 'Fax'}]},
#   'description': 'Bering Land Bridge National Preserve lies at the continental '
#                  'crossroad that greatly influenced the distribution of life '
#                  'in the Western Hemisphere during the Pleistocene Epoch. It '
#                  'is a vital landscape for indigenous communities who depend '
#                  'on the land just as their ancestors did for many '
#                  'generations. It is a wild and ecologically healthy landscape '
#                  'unlike any other.',
#   'designation': 'National Preserve',
#   'directionsInfo': 'The Bering Land Bridge Visitor Center is located in Nome, '
#                     'AK. Nome, AK is not on the road system and may be reached '
#                     'via a commercial flight. The Bering Land Bridge Visitor '
#                     'Center is located about a mile from Nome Airport. Bering '
#                     'Land Bridge National Preserve is located in the northern '
#                     'portion of the Seward Peninsula. There are no roads or '
#                     'trails into the parklands. Logistics on how to reach '
#                     'Bering Land Bridge is based on an individual’s resources '
#                     'and abilities.',
#   'directionsUrl': 'http://www.nps.gov/bela/planyourvisit/directions.htm',
#   'entranceFees': [{'cost': '0.00',
#                     'description': 'There is no fee to enter the preserve.',
#                     'title': 'Park Entrance'}],
#   'entrancePasses': [],
#   'fees': [],
#   'fullName': 'Bering Land Bridge National Preserve',
#   'id': 'EE1F4878-00FB-4760-A77F-EA76DB8DEFD9',
#   'images': [{'altText': 'Three wet muskox stand in a line.',
#               'caption': 'Three wet muskox.',
#               'credit': 'NPS / Roy Wood',
#               'title': 'Wet Muskox',
#               'url': 'https://www.nps.gov/common/uploads/structured_data/3C7A859F-1DD8-B71B-0B24F438FBCB2BE9.jpg'},
#              {'altText': 'A hiker is seen in the distance as autumn colors '
#                          'dominate the tundra landscape.',
#               'caption': 'Autumn hike at Bering Land Bridge',
#               'credit': 'NPS / Katie Cullen',
#               'title': 'Fall Colors',
#               'url': 'https://www.nps.gov/common/uploads/structured_data/3C7A8443-1DD8-B71B-0BDA7966D18282FC.jpg'},
#              {'altText': 'Rolling sand dunes with sparse vegetation with full '
#                          'moon rising above.',
#               'caption': 'Coastal moon rise',
#               'credit': 'NPS Photo',
#               'title': 'Coastal Moon Rise',
#               'url': 'https://www.nps.gov/common/uploads/structured_data/3C7A88A0-1DD8-B71B-0B4720E73A7F0534.jpg'},
#              {'altText': 'A vast expanse of undulating hills with granite '
#                          'spire jutting from the top.',
#               'caption': 'A small aircraft descends on Serpentine Hot Springs.',
#               'credit': 'NPS / Neal Herbert',
#               'title': 'Aerial View of Serpentine Hot Springs in Summer',
#               'url': 'https://www.nps.gov/common/uploads/structured_data/4E189372-A511-5F4D-17A56D6B9D2BD7E6.jpg'},
#              {'altText': 'Flock of shore birds taking flight',
#               'caption': 'Flock of shore birds taking flight',
#               'credit': 'NPS / Jim Pfeiffenberger',
#               'title': 'Flock of shore birds',
#               'url': 'https://www.nps.gov/common/uploads/structured_data/3C7A82A5-1DD8-B71B-0B79861422658B39.jpg'}],
#   'latLong': 'lat:65.96087902, long:-164.4086432',
#   'latitude': '65.96087902',
#   'longitude': '-164.4086432',
#   'name': 'Bering Land Bridge',
#   'operatingHours': [{'description': 'Bering Land Bridge Preserve is open 24/7 '
#                                      'year round. Due to its remote location '
#                                      'accessing the preserve can be '
#                                      'challenging, costly and time consuming.',
#                       'exceptions': [],
#                       'name': 'Bering Land Bridge National Preserve',
#                       'standardHours': {'friday': 'All Day',
#                                         'monday': 'All Day',
#                                         'saturday': 'All Day',
#                                         'sunday': 'All Day',
#                                         'thursday': 'All Day',
#                                         'tuesday': 'All Day',
#                                         'wednesday': 'All Day'}}],
#   'parkCode': 'bela',
#   'states': 'AK',
#   'topics': [{'id': '77B7EFDF-1A74-409C-8BA2-324EC919DB0E', 'name': 'Arctic'},
#              {'id': 'F16A7A2C-174D-4FD8-9203-8D8D8EAD644B',
#               'name': 'Geothermal'},
#              {'id': '2FC0C556-5B92-4217-AF03-AA395A207D7D',
#               'name': 'Hot Springs'},
#              {'id': '90F8744F-CD10-4925-955C-064CB1A17EB0',
#               'name': 'Volcanoes'}],
#   'url': 'https://www.nps.gov/bela/index.htm',
#   'weatherInfo': 'Weather in the Seward Peninsula is generally characterized '
#                  'by long freezing winters and short, cool summers. Coastal '
#                  'areas typically have mild weather, while the interior has '
#                  'greater seasonal variation in temperature and '
#                  'precipitation.'},
#  {'activities': [{'id': 'A59947B7-3376-49B4-AD02-C0423E08C5F7',
#                   'name': 'Camping'},
#                  {'id': '4A58AF13-E8FB-4530-B41A-97DF0B0C77B7',
#                   'name': 'Backcountry Camping'},
#                  {'id': 'D72206E4-6CD1-4441-A355-F8F1827466B1',
#                   'name': 'Flying'},
#                  {'id': 'C06FE528-9671-4EC1-909F-B7D3720A1D89',
#                   'name': 'Fixed Wing Flying'},
#                  {'id': '42FD78B9-2B90-4AA9-BC43-F10E9FEA8B5A',
#                   'name': 'Hands-On'},
#                  {'id': '19A59EFB-DF4B-4049-9EE1-A784CAC9C70C',
#                   'name': 'Arts and Crafts'},
#                  {'id': 'BFF8C027-7C8F-480B-A5F8-CD8CE490BFBA',
#                   'name': 'Hiking'},
#                  {'id': '7C37B79B-D02D-49EB-9020-3DB8299B748A',
#                   'name': 'Backcountry Hiking'},
#                  {'id': 'DF4A35E0-7983-4A3E-BC47-F37B872B0F25',
#                   'name': 'Junior Ranger Program'},
#                  {'id': '0B685688-3405-4E2A-ABBA-E3069492EC50',
#                   'name': 'Wildlife Watching'},
#                  {'id': '5A2C91D1-50EC-4B24-8BED-A2E11A1892DF',
#                   'name': 'Birdwatching'},
#                  {'id': 'C8F98B28-3C10-41AE-AA99-092B3B398C43',
#                   'name': 'Museum Exhibits'},
#                  {'id': '24380E3F-AD9D-4E38-BF13-C8EEB21893E7',
#                   'name': 'Shopping'},
#                  {'id': '467DC8B8-0B7D-436D-A026-80A22358F615',
#                   'name': 'Bookstore and Park Store'}],
#   'addresses': [{'city': 'Kotzebue',
#                  'line1': '171 3rd Ave',
#                  'line2': '',
#                  'line3': '',
#                  'postalCode': '99752',
#                  'stateCode': 'AK',
#                  'type': 'Physical'},
#                 {'city': 'Kotzebue',
#                  'line1': 'PO Box 1029',
#                  'line2': '',
#                  'line3': '',
#                  'postalCode': '99752',
#                  'stateCode': 'AK',
#                  'type': 'Mailing'}],
#   'contacts': {'emailAddresses': [{'description': '',
#                                    'emailAddress': 'wear_webmail@nps.gov'}],
#                'phoneNumbers': [{'description': '',
#                                  'extension': '',
#                                  'phoneNumber': '9074423890',
#                                  'type': 'Voice'},
#                                 {'description': '',
#                                  'extension': '',
#                                  'phoneNumber': '9074428316',
#                                  'type': 'Fax'}]},
#   'description': 'North of the Arctic Circle, the monument forms 70 miles of '
#                  'shoreline on the Chukchi Sea. More than 114 beach ridges '
#                  'provide evidence of human use for 5,000 years. The Inupiat '
#                  'continue to use the area today. Vast wetlands provide '
#                  'habitat for shorebirds from as far away as South America. '
#                  'Hikers and boaters can see carpets of wildflowers among '
#                  'shrubs containing wisps of qiviut from muskoxen.',
#   'designation': 'National Monument',
#   'directionsInfo': 'Cape Krusenstern National Monument lies within a remote '
#                     'area of northwest Alaska and is bordered by the Arctic '
#                     'Ocean and Chukchi Sea. Visitors generally access the '
# ...
#                          'School',
#               'credit': 'National Park Service',
#               'title': 'Kennecott Visitor Center',
#               'url': 'https://www.nps.gov/common/uploads/structured_data/9DE230BE-C2B2-38C5-DF6FF368C1AB8F0B.jpg'},
#              {'altText': 'Yakutat coastal area',
#               'caption': 'Yakutat coastal area',
#               'credit': 'National Park Service',
#               'title': 'Yakutat coastal area',
#               'url': 'https://www.nps.gov/common/uploads/structured_data/9DED0407-CD98-60E5-7965642A3CD2DA0D.jpg'}],
#   'latLong': 'lat:61.4182147, long:-142.6028439',
#   'latitude': '61.4182147',
#   'longitude': '-142.6028439',
#   'name': 'Wrangell - St Elias',
#   'operatingHours': [{'description': 'The park and public lands are always '
#                                      'open but visitor facilities have limited '
#                                      'seasons: Open in Summer. Call ahead for '
#                                      'hours: Dial-a-Ranger at Slana (907) '
#                                      '822-7401, Copper Center (907) 822-7250, '
#                                      'Chitina (907) 823-2205 and Kennecott '
#                                      '(907) 205-7106. CLOSED '
#                                      'Fall/Winter/Spring - October through '
#                                      'April.',
#                       'exceptions': [],
#                       'name': 'Wrangell-St. Elias National Park and Preserve',
#                       'standardHours': {'friday': 'Closed',
#                                         'monday': 'Closed',
#                                         'saturday': 'Closed',
#                                         'sunday': 'Closed',
#                                         'thursday': 'Closed',
#                                         'tuesday': 'Closed',
#                                         'wednesday': 'Closed'}}],
#   'parkCode': 'wrst',
#   'states': 'AK',
#   'topics': [{'id': '7F81A0CB-B91F-4896-B9A5-41BE9A54A27B',
#               'name': 'Archeology'},
#              {'id': '00F3C3F9-2D67-4802-81AE-CCEA5D3BA370', 'name': 'Arts'},
#              {'id': '9BD60DC0-C82B-42BA-A170-456B7423429D',
#               'name': 'Photography'},
#              {'id': 'B912363F-771C-4098-BA3A-938DF38A9D7E', 'name': 'Aviation'},
#              {'id': '12EA2B56-17EC-410A-A10D-BFBA87A0669B',
#               'name': 'Explorers and Expeditions'},
#              {'id': 'A1BAF33E-EA84-4608-A888-4CEE9541F027',
#               'name': 'Native American Heritage'},
#              {'id': '0D00073E-18C3-46E5-8727-2F87B112DDC6', 'name': 'Animals'},
#              {'id': '957EF2BD-AC6C-4B7B-BD9A-87593ADC6691', 'name': 'Birds'},
#              {'id': '324C31EC-7D75-41C7-AA28-EF8ACB5B6BF5', 'name': 'Bison'},
#              {'id': '2539614A-9646-446E-8251-34D3AAE068FA',
#               'name': 'Cats (wild)'},
#              {'id': '1608649A-E7D7-4529-BD83-074C90F9FB68', 'name': 'Fish'},
#              {'id': '9576386A-C84F-4436-9094-C5CD67A672CC', 'name': 'Wolves'},
#              {'id': '77B7EFDF-1A74-409C-8BA2-324EC919DB0E', 'name': 'Arctic'},
#              {'id': 'C8F16A24-90B7-47D9-B2E0-5F2A9237D0F4', 'name': 'Tundra'},
#              {'id': '4DC11D06-00F1-4A01-81D0-89CCCCE4FF50',
#               'name': 'Climate Change'},
#              {'id': '46FC5CBD-9AD5-48F1-B4DA-1357031B1D2E',
#               'name': 'Coasts, Islands and Atolls'},
#              {'id': '04A39AB8-DD02-432F-AE5F-BA1267D41A0D', 'name': 'Fire'},
#              {'id': '41B1A0A3-11FF-4F55-9CB9-034A7E28B087',
#               'name': 'Forests and Woodlands'},
#              {'id': '762170E5-0747-4836-B837-7F2547D3F733',
#               'name': 'Coniferous Forests'},
#              {'id': 'F6D3A52E-608F-47D6-96DF-1FD64122A2FC',
#               'name': 'Fossils and Paleontology'},
#              {'id': '66FB98FF-DAFC-4AD0-89C3-E181870E03A5', 'name': 'Dinosaur'},
#              {'id': 'F0F97E32-2F29-41B4-AF98-9FBE8DAB36B1', 'name': 'Geology'},
#              {'id': '087E5290-E130-49C1-ADFB-DAFB0644DBE4',
#               'name': 'Mineral Deposits'},
#              {'id': 'FBB14C45-1663-4714-9D28-B2B99874644D', 'name': 'Glaciers'},
#              {'id': '1CF1F6BB-A037-445B-8CF2-81428E50CE52', 'name': 'Lakes'},
#              {'id': '101F4D51-F99D-45A6-BBB6-CD481E5FACED',
#               'name': 'Mountains'},
#              {'id': 'A7359FC4-DAD8-45F5-AF15-7FF62F816ED3',
#               'name': 'Night Sky'},
#              {'id': 'B5E62BF4-5AE6-4100-8DE1-66652943FAEC',
#               'name': 'Aurora Borealis'},
#              {'id': '5BE55D7F-BDB6-4E3D-AC35-2D8EBB974417', 'name': 'Trails'},
#              {'id': '90F8744F-CD10-4925-955C-064CB1A17EB0',
#               'name': 'Volcanoes'},
#              {'id': 'BA12B386-49EA-46B0-9121-FCACACC47538',
#               'name': 'Watersheds'},
#              {'id': 'B85866E2-0897-4000-9040-605CA335804F',
#               'name': 'Wilderness'}],
#   'url': 'https://www.nps.gov/wrst/index.htm',
#   'weatherInfo': 'Varies widely depending on location in park and time of '
#                  'year. Visit '
#                  'https://www.nps.gov/wrst/planyourvisit/weather.htm for '
#                  'detailed information.'},
#  {'activities': [{'id': '071BA73C-1D3C-46D4-A53C-00D5602F7F0E',
#                   'name': 'Boating'},
#                  {'id': 'E0E4CE55-3119-46DE-86EB-6817CD8D5F30',
#                   'name': 'Motorized Boating'},
#                  {'id': 'A59947B7-3376-49B4-AD02-C0423E08C5F7',
#                   'name': 'Camping'},
#                  {'id': '4A58AF13-E8FB-4530-B41A-97DF0B0C77B7',
#                   'name': 'Backcountry Camping'},
#                  {'id': '907E8125-15E4-483C-8EAD-B9FA1E85C6F8',
#                   'name': 'Canoe or Kayak Camping'},
#                  {'id': '8C495067-8E94-4D78-BBD4-3379DACF6550',
#                   'name': 'Dog Sledding'},
#                  {'id': 'AE42B46C-E4B7-4889-A122-08FE180371AE',
#                   'name': 'Fishing'},
#                  {'id': 'BFF8C027-7C8F-480B-A5F8-CD8CE490BFBA',
#                   'name': 'Hiking'},
#                  {'id': '7C37B79B-D02D-49EB-9020-3DB8299B748A',
#                   'name': 'Backcountry Hiking'},
#                  {'id': '8386EEAF-985F-4DE8-9037-CCF91975AC94',
#                   'name': 'Hunting and Gathering'},
#                  {'id': '25559F45-F162-4B8B-BEC2-B341034A2AF4',
#                   'name': 'Hunting'},
#                  {'id': '4D224BCA-C127-408B-AC75-A51563C42411',
#                   'name': 'Paddling'},
#                  {'id': '21DB3AFC-8AAC-4665-BC1F-7198C0685983',
#                   'name': 'Canoeing'},
#                  {'id': 'F353A9ED-4A08-456E-8DEC-E61974D0FEB6',
#                   'name': 'Kayaking'},
#                  {'id': '75B92BEB-A36D-4064-88B7-92EEC6D17611',
#                   'name': 'Whitewater Rafting'},
#                  {'id': 'F9B1D433-6B86-4804-AED7-B50A519A3B7C',
#                   'name': 'Skiing'},
#                  {'id': 'EAB1EBDE-5B72-493F-8F8F-0EE5B1724436',
#                   'name': 'Cross-Country Skiing'},
#                  {'id': '7C912B83-1B1B-4807-9B66-97C12211E48E',
#                   'name': 'Snowmobiling'},
#                  {'id': '0B685688-3405-4E2A-ABBA-E3069492EC50',
#                   'name': 'Wildlife Watching'},
#                  {'id': '5A2C91D1-50EC-4B24-8BED-A2E11A1892DF',
#                   'name': 'Birdwatching'}],
#   'addresses': [{'city': 'Fairbanks',
#                  'line1': '101 Dunkel St',
#                  'line2': 'Suite 110',
#                  'line3': '',
#                  'postalCode': '99701',
#                  'stateCode': 'AK',
#                  'type': 'Physical'},
#                 {'city': 'Fairbanks',
#                  'line1': '101 Dunkel St',
#                  'line2': 'Suite 110',
#                  'line3': '',
#                  'postalCode': '99701',
#                  'stateCode': 'AK',
#                  'type': 'Mailing'}],
#   'contacts': {'emailAddresses': [{'description': '',
#                                    'emailAddress': 'fair_information@nps.gov'}],
#                'phoneNumbers': [{'description': '',
#                                  'extension': '',
#                                  'phoneNumber': '907-459-3730',
#                                  'type': 'Voice'}]},
#   'description': 'Located in Interior Alaska, Yukon-Charley Rivers offers '
#                  'exploration in a largely untouched landscape. Whether you '
#                  "float the mighty Yukon River or paddle the Charley River's "
#                  'whitewater, your memories will last a lifetime. Geology, '
#                  'cultural history, gold rush remnants, wildlife, and vast '
#                  'scenery will be a part of your experience. But, the '
#                  'strongest element will be solitude. Your adventure awaits.',
#   'designation': 'National Preserve',
#   'directionsInfo': 'Although there is no direct highway connection to '
#                     'Yukon-Charley Rivers National Preserve, visitors are able '
#                     'to access the preserve by either air travel from '
#                     'Fairbanks, or water or air travel from two small towns on '
#                     'the road system(Eagle and Circle), near the preserve '
#                     'boundaries.',
#   'directionsUrl': 'http://www.nps.gov/yuch/planyourvisit/directions.htm',
#   'entranceFees': [{'cost': '0.00',
#                     'description': 'There is no entrance fee for Yukon-Charley '
#                                    'Rivers National Preserve',
#                     'title': 'Entrance Fee'}],
#   'entrancePasses': [],
#   'fees': [],
#   'fullName': 'Yukon - Charley Rivers National Preserve',
#   'id': '6F550E4D-AE26-4250-A674-397E2DF88092',
#   'images': [{'altText': 'Aerial view of the Yukon River during fall colors',
#               'caption': 'The Yukon River is a vast body of water that has '
#                          'carved its path into the landscape over millions of '
#                          'years.',
#               'credit': 'NPS Photo / Josh Spice',
#               'title': 'Aerial view of the Yukon River',
#               'url': 'https://www.nps.gov/common/uploads/structured_data/5441BF50-05AD-F33E-6A0339476B5B18EF.jpg'},
#              {'altText': 'Historic Coal Creek Dredge',
#               'caption': 'The historic Coal Creek Dredge sits nonoperational '
#                          "at its original site, near Slaven's Roadhouse",
#               'credit': 'NPS Photo / Josh Spice',
#               'title': 'Coal Creek Dredge',
#               'url': 'https://www.nps.gov/common/uploads/structured_data/3C7A625C-1DD8-B71B-0B937F599D9D10DF.jpg'},
#              {'altText': 'Eagle Visitor Center in front of Eagle Bluff',
#               'caption': 'The Eagle Visitor Center sits atop a small bluff '
#                          'overlooking the Yukon River.',
#               'credit': 'NPS Photo / Greg Kinman',
#               'title': 'Eagle Visitor Center',
#               'url': 'https://www.nps.gov/common/uploads/structured_data/3C7A6453-1DD8-B71B-0BD5799A0348C713.jpg'},
#              {'altText': "Slaven's Roadhouse during fall colors",
#               'caption': 'A historic roadhouse and public use cabin on the '
#                          'Yukon River',
#               'credit': 'NPS Photo / Josh Spice',
#               'title': "Slaven's Roadhouse during fall colors",
#               'url': 'https://www.nps.gov/common/uploads/structured_data/56A9969F-9BE7-F7A4-2DF42106328FEFBE.jpg'},
#              {'altText': 'Calico Bluff rising above the Yukon River that also '
#                          'winds into the distance behind the bluff',
#               'caption': 'Calico Bluff, showing 4 million years of rock '
#                          'layers, rises above the Yukon River and is one of '
#                          'many bluffs along the 130 miles of river in the '
#                          'preserve',
#               'credit': 'NPS Photo / Josh Spice',
#               'title': 'Calico Bluff and the Yukon River',
#               'url': 'https://www.nps.gov/common/uploads/structured_data/576A1897-A20F-B183-CE6A8AB15207E519.jpg'},
#              {'altText': 'Aerial view of the Charley River winding through the '
#                          'tundra and mountains',
#               'caption': "The 105 mile-long Wild and Scenic Charley River's "
#                          'watershed is completely protected within the '
#                          'preserve boundary.',
#               'credit': 'NPS Photo / Josh Spice',
#               'title': 'The Wild and Scenic Charley River',
#               'url': 'https://www.nps.gov/common/uploads/structured_data/586B0BCE-D61C-2105-5C518EB2E5A138C0.jpg'}],
#   'latLong': 'lat:65.0935608, long:-142.7960021',
#   'latitude': '65.0935608',
#   'longitude': '-142.7960021',
#   'name': 'Yukon - Charley Rivers',
#   'operatingHours': [{'description': 'The preserve is open 24-hours a day',
#                       'exceptions': [],
#                       'name': 'Open 24-hours',
#                       'standardHours': {'friday': 'All Day',
#                                         'monday': 'All Day',
#                                         'saturday': 'All Day',
#                                         'sunday': 'All Day',
#                                         'thursday': 'All Day',
#                                         'tuesday': 'All Day',
#                                         'wednesday': 'All Day'}}],
#   'parkCode': 'yuch',
#   'states': 'AK',
#   'topics': [{'id': '7F81A0CB-B91F-4896-B9A5-41BE9A54A27B',
#               'name': 'Archeology'},
#              {'id': '7F12224B-217A-4B07-A4A2-636B1CE7F221',
#               'name': 'Colonization and Settlement'},
#              {'id': '12EA2B56-17EC-410A-A10D-BFBA87A0669B',
#               'name': 'Explorers and Expeditions'},
#              {'id': '0B575E33-B68F-4F3D-998E-B03284606CF3', 'name': 'Industry'},
#              {'id': 'BDC806A8-5470-4A8B-A0F9-CD804BE3028A', 'name': 'Mining'},
#              {'id': '3B0D607D-9933-425A-BFA0-21529AC4734C', 'name': 'Military'},
#              {'id': '97CCB419-196C-4B95-BB3A-621458F78415', 'name': 'US Army'},
#              {'id': 'A1BAF33E-EA84-4608-A888-4CEE9541F027',
#               'name': 'Native American Heritage'},
#              {'id': 'A160B3D9-1603-4D89-B82F-21FCAF9EEE3B',
#               'name': 'Tragic Events'},
#              {'id': 'D91B6F1A-FED8-490D-B181-9940474CD67C', 'name': 'Floods'},
#              {'id': 'C9C749E3-39C3-45F7-BCC5-9A609E30AA05',
#               'name': 'Westward Expansion'},
#              {'id': '83DDFE66-914E-4402-AD3E-ACA731AB2537',
#               'name': 'The Gold Rush'},
#              {'id': '0D00073E-18C3-46E5-8727-2F87B112DDC6', 'name': 'Animals'},
#              {'id': '957EF2BD-AC6C-4B7B-BD9A-87593ADC6691', 'name': 'Birds'},
#              {'id': '9576386A-C84F-4436-9094-C5CD67A672CC', 'name': 'Wolves'},
#              {'id': '77B7EFDF-1A74-409C-8BA2-324EC919DB0E', 'name': 'Arctic'},
#              {'id': 'C8F16A24-90B7-47D9-B2E0-5F2A9237D0F4', 'name': 'Tundra'},
#              {'id': '04A39AB8-DD02-432F-AE5F-BA1267D41A0D', 'name': 'Fire'},
#              {'id': 'F0F97E32-2F29-41B4-AF98-9FBE8DAB36B1', 'name': 'Geology'},
#              {'id': 'A7359FC4-DAD8-45F5-AF15-7FF62F816ED3',
#               'name': 'Night Sky'},
#              {'id': 'B5E62BF4-5AE6-4100-8DE1-66652943FAEC',
#               'name': 'Aurora Borealis'},
#              {'id': '5BE55D7F-BDB6-4E3D-AC35-2D8EBB974417', 'name': 'Trails'},
#              {'id': '596BAA6D-F66B-4348-8433-FEFF35A8005E',
#               'name': 'Water Trails'},
#              {'id': 'BA12B386-49EA-46B0-9121-FCACACC47538',
#               'name': 'Watersheds'},
#              {'id': 'B85866E2-0897-4000-9040-605CA335804F',
#               'name': 'Wilderness'}],
#   'url': 'https://www.nps.gov/yuch/index.htm',
#   'weatherInfo': 'The area that Yukon-Charley Rivers encompasses is generally '
#                  'classified as sub-arctic, with exceptionally cold winters, '
#                  'relatively warm summers, low annual precipitation, and '
#                  'generally high winds.'}]

# %%
park_data_details_with_entry_fee = []
for park in parks_data['data']:
    for i in park:
        for fee in i['entranceFees']:
            park_data_details_with_entry_fee.append({
                'parkCode': i['parkCode'],
                'states' : i['states'],
                'fullName': i['fullName'],
                'designation': i['designation'],
                'latitude': i['latitude'],
                'longitude': i['longitude'],
                'latLong': i['latLong'],
                'fee_usd': fee['cost'],
                'fee_type': fee['title'],
                'fee_description': fee['description']})

# %%
park_data_details_with_entry_fee = pd.DataFrame(park_data_details_with_entry_fee)
print(park_data_details_with_entry_fee)
# Out:
#      parkCode                   states  \
# 0        alag                       AK
# 1        anch                       AK
# 2        aleu                       AK
# 3        aleu                       AK
# 4        ania                       AK
# ...       ...                      ...
# 1062     oreg     ID,KS,MO,NE,OR,WA,WY
# 1063     poex  CA,CO,KS,MO,NE,NV,UT,WY
# 1064     yell                 ID,MT,WY
# 1065     yell                 ID,MT,WY
# 1066     yell                 ID,MT,WY
#
#                                                fullName  \
# 0                                    Alagnak Wild River
# 1                                   Alaska Public Lands
# 2     Aleutian Islands World War II National Histori...
# 3     Aleutian Islands World War II National Histori...
# 4                Aniakchak National Monument & Preserve
# ...                                                 ...
# 1062                     Oregon National Historic Trail
# 1063               Pony Express National Historic Trail
# 1064                          Yellowstone National Park
# 1065                          Yellowstone National Park
# 1066                          Yellowstone National Park
#
#                        designation       latitude       longitude  \
# 0                       Wild River    59.05180188     -156.112002
# 1                                         61.2188     -149.894536
# 2           National Historic Area        53.9143       -166.5197
# 3           National Historic Area        53.9143       -166.5197
# 4     National Monument & Preserve    56.85317675    -157.5544362
# ...                            ...            ...             ...
# 1062       National Historic Trail  41.9876977831  -109.634200841
# 1063       National Historic Trail  42.2365761128  -109.266148417
# 1064                 National Park    44.59824417    -110.5471695
# 1065                 National Park    44.59824417    -110.5471695
# 1066                 National Park    44.59824417    -110.5471695
#
#                                      latLong fee_usd  \
# 0          lat:59.05180188, long:-156.112002    0.00
# 1              lat:61.2188, long:-149.894536    0.00
# 2                lat:53.9143, long:-166.5197    6.00
# 3                lat:53.9143, long:-166.5197   10.00
# 4         lat:56.85317675, long:-157.5544362    0.00
# ...                                      ...     ...
# 1062  lat:41.9876977831, long:-109.634200841    0.00
# 1063  lat:42.2365761128, long:-109.266148417    0.00
# 1064      lat:44.59824417, long:-110.5471695   35.00
# 1065      lat:44.59824417, long:-110.5471695   30.00
# 1066      lat:44.59824417, long:-110.5471695   20.00
#
#                                              fee_type  \
# 0                                    No Entrance Free
# 1                                     Free Admittance
# 2                        Land Use Permit - one person
# 3                            Land Use Permit - family
# 4                                     No Entrance Fee
# ...                                               ...
# 1062                  Entrance fees vary site by site
# 1063                  Entrance fees vary site by site
# 1064             Yellowstone (non-commercial vehicle)
# 1065           Yellowstone (motorcycle or snowmobile)
# 1066  Yellowstone (individual on foot, bicycle, etc.)
#
#                                         fee_description
# 0                                 None. There is no fee
# 1             No entry fee to visit the visitors center
# 2     The park is on private land owned by the Ounal...
# 3     The park is on private land owned by the Ounal...
# 4     There is no fee to enter Aniakchak National Mo...
# ...                                                 ...
# 1062  There are no user or entry fees for the Oregon...
# 1063  There are no user or entry fees for the Pony E...
# 1064  Good for entry into Yellowstone National Park ...
# 1065  Good for entry into Yellowstone National Park ...
# 1066  Good for entry into Yellowstone National Park ...
#
# [1067 rows x 10 columns]

# %%
entry_fees_df = pd.DataFrame(park_data_details_with_entry_fee)
entry_fees_df = entry_fees_df[['parkCode','states', 'fullName', 'designation', 'latitude', 'longitude','latLong','fee_usd','fee_type','fee_description']]
entry_fees_df['fee_usd'] = entry_fees_df['fee_usd'].astype(float)
entry_fees_df.head(40)
# Out:
#    parkCode                      states  \
# 0      alag                          AK
# 1      anch                          AK
# 2      aleu                          AK
# 3      aleu                          AK
# 4      ania                          AK
# 5      bela                          AK
# 6      cakr                          AK
# 7      dena                          AK
# 8      dena                          AK
# 9      gaar                          AK
# 10     glba                          AK
# 11     inup                          AK
# 12     inup                          AK
# 13     inup                          AK
# 14     inup                          AK
# 15     inup                          AK
# 16     inup                          AK
# 17     katm                          AK
# 18     kefj                          AK
# 19     klgo                          AK
# 20     kova                          AK
# 21     lacl                          AK
# 22     noat                          AK
# 23     sitk                          AK
# 24     wrst                          AK
# 25     yuch                          AK
# 26     bicr                          AL
# 27     bicr                          AL
# 28     frri                          AL
# 29     hobe                          AL
# 30     liri                          AL
# 31     liri                          AL
# 32     natt                    AL,MS,TN
# 33     natr                    AL,MS,TN
# 34     ruca                          AL
# 35     semo                          AL
# 36     trte  AL,AR,GA,IL,KY,MO,NC,OK,TN
# 37     tuai                          AL
# 38     tuin                          AL
# 39     arpo                          AR
#
#                                              fullName  \
# 0                                  Alagnak Wild River
# 1                                 Alaska Public Lands
# 2   Aleutian Islands World War II National Histori...
# 3   Aleutian Islands World War II National Histori...
# 4              Aniakchak National Monument & Preserve
# 5                Bering Land Bridge National Preserve
# 6                  Cape Krusenstern National Monument
# 7                     Denali National Park & Preserve
# 8                     Denali National Park & Preserve
# 9        Gates Of The Arctic National Park & Preserve
# 10               Glacier Bay National Park & Preserve
# 11                            Iñupiat Heritage Center
# 12                            Iñupiat Heritage Center
# 13                            Iñupiat Heritage Center
# 14                            Iñupiat Heritage Center
# 15                            Iñupiat Heritage Center
# 16                            Iñupiat Heritage Center
# 17                    Katmai National Park & Preserve
# 18                         Kenai Fjords National Park
# 19        Klondike Gold Rush National Historical Park
# 20                         Kobuk Valley National Park
# 21                Lake Clark National Park & Preserve
# 22                           Noatak National Preserve
# 23                     Sitka National Historical Park
# 24       Wrangell - St Elias National Park & Preserve
# 25           Yukon - Charley Rivers National Preserve
# 26          Birmingham Civil Rights National Monument
# 27          Birmingham Civil Rights National Monument
# 28                   Freedom Riders National Monument
# 29              Horseshoe Bend National Military Park
# 30              Little River Canyon National Preserve
# 31              Little River Canyon National Preserve
# 32                Natchez Trace National Scenic Trail
# 33                              Natchez Trace Parkway
# 34                     Russell Cave National Monument
# 35        Selma To Montgomery National Historic Trail
# 36             Trail Of Tears National Historic Trail
# 37             Tuskegee Airmen National Historic Site
# 38          Tuskegee Institute National Historic Site
# 39                    Arkansas Post National Memorial
#
#                      designation       latitude       longitude  \
# 0                     Wild River    59.05180188     -156.112002
# 1                                       61.2188     -149.894536
# 2         National Historic Area        53.9143       -166.5197
# 3         National Historic Area        53.9143       -166.5197
# 4   National Monument & Preserve    56.85317675    -157.5544362
# 5              National Preserve    65.96087902    -164.4086432
# 6              National Monument    67.41499986    -163.5037786
# 7       National Park & Preserve    63.29777484    -151.0526568
# 8       National Park & Preserve    63.29777484    -151.0526568
# 9       National Park & Preserve    67.75961636    -153.2917758
# 10      National Park & Preserve    58.80086718    -136.8407579
# 11                                  71.29832445    -156.7535863
# 12                                  71.29832445    -156.7535863
# 13                                  71.29832445    -156.7535863
# 14                                  71.29832445    -156.7535863
# 15                                  71.29832445    -156.7535863
# 16                                  71.29832445    -156.7535863
# 17      National Park & Preserve    58.62235668    -155.0126574
# 18                 National Park    59.81804414     -150.106502
# 19      National Historical Park    59.61042373    -135.2618535
# 20                 National Park    67.35631336    -159.2002293
# 21      National Park & Preserve    60.57405857      -153.55535
# 22             National Preserve    68.01027053     -159.831694
# 23      National Historical Park    57.04718173    -135.3156876
# 24      National Park & Preserve     61.4182147    -142.6028439
# 25             National Preserve     65.0935608    -142.7960021
# 26             National Monument  33.5154266357   -86.814666748
# 27             National Monument  33.5154266357   -86.814666748
# 28             National Monument   33.635269165  -85.9064331055
# 29        National Military Park    32.97668879    -85.73413589
# 30             National Preserve    34.41461863    -85.61734327
# 31             National Preserve    34.41461863    -85.61734327
# 32         National Scenic Trail   34.330290333  -88.7100104094
# 33                       Parkway    33.78002293    -89.03092439
# 34             National Monument    34.97402063    -85.81560314
# 35       National Historic Trail    32.27082092    -86.72823702
# 36       National Historic Trail  36.0530021046  -89.6761041963
# 37        National Historic Site    32.45538671    -85.67983321
# 38        National Historic Site    32.42962115    -85.70488498
# 39             National Memorial    34.00389998    -91.30837178
#
#                                    latLong  fee_usd  \
# 0        lat:59.05180188, long:-156.112002      0.0
# 1            lat:61.2188, long:-149.894536      0.0
# 2              lat:53.9143, long:-166.5197      6.0
# 3              lat:53.9143, long:-166.5197     10.0
# 4       lat:56.85317675, long:-157.5544362      0.0
# 5       lat:65.96087902, long:-164.4086432      0.0
# 6       lat:67.41499986, long:-163.5037786      0.0
# 7       lat:63.29777484, long:-151.0526568     15.0
# 8       lat:63.29777484, long:-151.0526568     45.0
# 9       lat:67.75961636, long:-153.2917758      0.0
# 10      lat:58.80086718, long:-136.8407579      0.0
# 11      lat:71.29832445, long:-156.7535863     10.0
# 12      lat:71.29832445, long:-156.7535863      5.0
# 13      lat:71.29832445, long:-156.7535863      5.0
# 14      lat:71.29832445, long:-156.7535863      0.0
# 15      lat:71.29832445, long:-156.7535863      0.0
# 16      lat:71.29832445, long:-156.7535863      0.0
# 17      lat:58.62235668, long:-155.0126574      0.0
# 18       lat:59.81804414, long:-150.106502      0.0
# 19      lat:59.61042373, long:-135.2618535      0.0
# 20      lat:67.35631336, long:-159.2002293      0.0
# 21        lat:60.57405857, long:-153.55535      0.0
# 22       lat:68.01027053, long:-159.831694      0.0
# 23      lat:57.04718173, long:-135.3156876      0.0
# 24       lat:61.4182147, long:-142.6028439      0.0
# 25       lat:65.0935608, long:-142.7960021      0.0
# 26   lat:33.5154266357, long:-86.814666748      0.0
# 27   lat:33.5154266357, long:-86.814666748     15.0
# 28   lat:33.635269165, long:-85.9064331055      0.0
# 29      lat:32.97668879, long:-85.73413589      0.0
# 30      lat:34.41461863, long:-85.61734327     15.0
# 31      lat:34.41461863, long:-85.61734327     35.0
# 32   lat:34.330290333, long:-88.7100104094      0.0
# 33      lat:33.78002293, long:-89.03092439      0.0
# 34      lat:34.97402063, long:-85.81560314      0.0
# 35      lat:32.27082092, long:-86.72823702      0.0
# 36  lat:36.0530021046, long:-89.6761041963      0.0
# 37      lat:32.45538671, long:-85.67983321      0.0
# 38      lat:32.42962115, long:-85.70488498      0.0
# 39      lat:34.00389998, long:-91.30837178      0.0
#
#                                            fee_type  \
# 0                                  No Entrance Free
# 1                                   Free Admittance
# 2                      Land Use Permit - one person
# 3                          Land Use Permit - family
# 4                                   No Entrance Fee
# 5                                     Park Entrance
# 6                                     Free Entrance
# 7                     Denali Individual Weekly Pass
# 8                                Denali Annual Pass
# 9                                      Entrance Fee
# 10                                  No Entrance Fee
# 11                                           Adults
# 12                                            Youth
# 13                                 College students
# 14                                           Elders
# 15                                         Children
# 16                    North Slope Borough Residents
# 17                Katmai National Park and Preserve
# 18                                  No Entrance Fee
# 19                                        Entry Fee
# 20                                    Free Entrance
# 21                Lake Clark Entrance and User Fees
# 22                                    Free Entrance
# 23                     All Park Activities are Free
# 24                                     Entrance Fee
# 25                                     Entrance Fee
# 26        Birmingham Civil Rights National Monument
# 27  Birmingham Civil Rights Institute Entrance Fees
# 28                 Freedom Riders National Monument
# 29         Horseshoe Bend Entrance Fee - Per Person
# 30         Canyon Mouth Park picnic area Daily Pass
# 31        Canyon Mouth Park picnic area Annual Pass
# 32                                  No entrance fee
# 33                                  No entrance fee
# 34                              Entrance Fee "FREE"
# 35                                     Entrance Fee
# 36                 General Entrance Fee Information
# 37                     Tuskegee Airmen Entrance Fee
# 38                  Tuskegee Institute Entrance Fee
# 39                                        Park Fees
#
#                                       fee_description
# 0                               None. There is no fee
# 1           No entry fee to visit the visitors center
# 2   The park is on private land owned by the Ounal...
# 3   The park is on private land owned by the Ounal...
# 4   There is no fee to enter Aniakchak National Mo...
# 5              There is no fee to enter the preserve.
# 6   There is no fee required to visit Cape Krusens...
# 7             Admits one individual, 16 years and up.
# 8   This pass is valid for 12 months from the date...
# 9   There is no entrance fee for Gates of the Arctic.
# 10  There is no entrance fee to enter Glacier Bay ...
# 11                                 Adults (Age 18-59)
# 12                                   Youth (Age 7-17)
# 13
# 14                                   Elders (Age 60+)
# 15                         Children (Age 6 and under)
# 16                   Residents of North Slope Borough
# 17               There is no entrance fee for Katmai.
# 18  No entrance fees are charged at Kenai Fjords N...
# 19  Entry to Klondike Gold Rush National Historica...
# 20  There is no entrance fee to visit Kobuk Valley...
# 21  You do not need to pay fees, make reservations...
# 22  There is no fee to visit Noatak National Preserve
# 23  There is no fee to enter the visitor center, p...
# 24                                      Fee free park
# 25  There is no entrance fee for Yukon-Charley Riv...
# 26  No Entrance Fee. The interior of the A.G. Gast...
# 27  Adults $15 ea.\n\nSeniors (age 65+) $13 ea.\n\...
# 28  Freedom Riders National Monument does not have...
# 29                 Horseshoe Bend is a fee free Park.
# 30  Located near Cedar Bluff, Alabama, the Canyon ...
# 31  Located near Cedar Bluff, Alabama, the Canyon ...
# 32  There is no fee to enter the Natchez Trace Par...
# 33  There is no fee to enter the Natchez Trace Par...
# 34         There is not an entrance fee to this park.
# 35  There are no entrance fees along Selma to Mont...
# 36  There are NO USER OR ENTRY FEES fees for the T...
# 37  There are no entrance fees for Tuskegee Airmen...
# 38  There are no entrance fees for Tuskegee Instit...
# 39        There is no entrance fee to visit the park.

# %%
final_df = entry_fees_df.drop_duplicates()

# %%
final_df.to_csv('NPS_all_states_entry_fees_df.csv', index=False)
